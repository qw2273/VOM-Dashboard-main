# %%
# Created by WUQ2 at 3/24/2023
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dir = r"C:\Users\wuq2\Documents\wwn\vom"
data_folder_dir = os.path.join(dir,  "data" )
global data_folder_dir

question_list  = ['Timestamp', 'Location', 'How long have you been at Whirlpool?', 'What new Whirlpool policy, benefit, or initiative would be most beneficial to your career development?', 'I understand WWN’s mission to successfully create an inclusive & equitable environment that enables a natural desire to stay & be committed to Whirlpool.', 'I am actively engaged in WWN activities that help drive an inclusive & equitable environment that enables a natural desire to stay & be committed to Whirlpool.', 'Job Level', 'In the past year, which WWN initiatives have you leveraged? Please select all that apply:', 'If you are not currently actively engaged in WWN, what would inspire you to become more involved?',   'In the past year, which Whirlpool employee resources have you leveraged? Please select all that apply:', 'How long have you been a member of WWN?', 'What Whirlpool policy, benefit, or initiative is most supportive of your career development?', 'The Every Day Performance Excellence process is successful in differentiating talent and supporting advancement for women at Whirlpool.', 'Function', 'There are policies, benefits, and initiatives in place to ensure my success as a woman at Whirlpool.', 'How could WWN make the biggest impact for women at Whirlpool in the coming year?', 'Why is supporting WWN important to you (as a female or an ally)?']
columns_to_keep = question_list + ["What area would you most like to see WWN focus on in next year? Please choose TWO:"]
global columns_to_keep

def get_data() -> pd.DataFrame:
    df = None
    for f in os.listdir( data_folder_dir):
        year_str = f.split("_")[-1].split('.')[0]
        _df=pd.read_excel(os.path.join ( data_folder_dir, f) )
        _df.rename(columns = {f"What area would you most like to see WWN focus on in {int(year_str) + 1 }? Please choose TWO:":
                           "What area would you most like to see WWN focus on in next year? Please choose TWO:"}, inplace = True)
        _df=_df[columns_to_keep]
        df=pd.concat([df, _df],  axis=0)
 
    return df

# %% [markdown]
# ## read data ####

# %%
df  = get_data()
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['year'] = df['Timestamp'].dt.year

# %%
YEAR_LIST = df['year'].unique().tolist()

# %%
YEAR_LIST
# Out:
# [2021, 2022]

# %% [markdown]
# ## remap question

# %%
section_mapping  = {'s1': 'Membership Demographics',
 's2': 'Membership Suppot',
 's3': 'Membership Commitment'}

# %%
question_mapping = {    
    "s1" : [  'Job Level', 'Function', 'Location',\
       'How long have you been at Whirlpool?',
       'How long have you been a member of WWN?'], 
    
  "s2" :      [ 'There are policies, benefits, and initiatives in place to ensure my success as a woman at Whirlpool.',
       'The Every Day Performance Excellence process is successful in differentiating talent and supporting advancement for women at Whirlpool.',
       'What Whirlpool policy, benefit, or initiative is most supportive of your career development?',
       'What new Whirlpool policy, benefit, or initiative would be most beneficial to your career development?',
      'What area would you most like to see WWN focus on in next year? Please choose TWO:',
       'In the past year, which WWN initiatives have you leveraged? Please select all that apply:',
       'In the past year, which Whirlpool employee resources have you leveraged? Please select all that apply:'], 
        
  "s3" :   [ 'I understand WWN’s mission to successfully create an inclusive & equitable environment that enables a natural desire to stay & be committed to Whirlpool.',
       'I am actively engaged in WWN activities that help drive an inclusive & equitable environment that enables a natural desire to stay & be committed to Whirlpool.',
       'If you are not currently actively engaged in WWN, what would inspire you to become more involved?',
       'Why is supporting WWN important to you (as a female or an ally)?',
       'How could WWN make the biggest impact for women at Whirlpool in the coming year?']
}

# %%
question_column_remap = []
for s_num, qst_list in question_mapping.items():
    for q_num, qst in enumerate(qst_list):
        question_column_remap.append([ s_num, "q" + str(q_num +1 ),  section_mapping.get(s_num), qst] )

# %%
question_column_remap = pd.DataFrame(data = question_column_remap, columns = ['section_num',  'question_num', 'section', 'question'])

# %%
question_column_remap['section_question_num'] = question_column_remap['section_num'] + '_' + question_column_remap['question_num']

# %%
column_rename_dict = question_column_remap.groupby(['question'])['section_question_num'].max().to_dict()

# %%
df.columns   = [ column_rename_dict.get( col, col) for col in df.columns  ]

# %%
df.head(2)
# Out:
#                 Timestamp   s1_q3      s1_q4  \
# 0 2021-09-01 09:47:54.842  Remote  4-9 years
# 1 2021-09-08 09:39:50.113  Remote  10+ years
#
#                                                s2_q4  s3_q1  s3_q2  \
# 0  - A new rating system \n- Promotions allowed t...      5      5
# 1                    9 box transparency and coaching      5      5
#
#             s1_q1                                              s2_q6  \
# 0  Senior Analyst  Networking / Social Events, Policy Education, ...
# 1  Senior Manager                         Career Compass Round Robin
#
#                                                s3_q3  \
# 0  I wish that the pillars got together more to s...
# 1                                                NaN
#
#                                                s2_q7      s1_q5  \
# 0  Employee Well-Being & Support Channel / WHR360...  4-9 years
# 1                          Whirlpool Human Resources  1-3 years
#
# ...

# %% [markdown]
# # section 0: total number of responses

# %%
tot_num_of_responses = df.groupby("year").size()
tot_num_of_responses
# Out:
# year
# 2021    194
# 2022    183
# dtype: int64

# %%
tot_num_of_responses.plot(kind = 'bar', figsize = (4,2))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
tot_num_of_responses.diff()
# Out:
# year
# 2021     NaN
# 2022   -11.0
# dtype: float64

# %% [markdown]
# # Section 1 : Demographics

# %% [markdown]
# ## job level
# -  % of members by job level
# -  As compared to year 2021, in year 2022, we've seen more manager and director and above level joined wwn
# - new members increase/drop by job level, function

# %%
df['s1_q1']  =  np.where(df['s1_q1'].isnull(), 'No response', df['s1_q1'])

# %%
df['s1_q1'].unique ()
# Out:
# array(['Senior Analyst', 'Senior Manager', 'Analyst', 'Associate',
#        'Manager', 'Director/Senior Director', 'VP and above',
#        'No response'], dtype=object)

# %% [markdown]
# ## pie chart for each year group

# %%
for year in YEAR_LIST: 
    tmp = df.groupby('year')['s1_q1'].value_counts(normalize = True).loc[year]
    tmp.plot(kind = 'pie')
    plt.ylabel("")
    plt.show()

# %% [markdown]
# ### compare YOY membership count change by job level

# %%
member_by_job_lvl_year =\
df.groupby('s1_q1', as_index = False)['year'].value_counts().sort_values(by = ['s1_q1', 'year'])

# %%
fig, ax = plt.subplots (figsize= (5,3))
sns.barplot(member_by_job_lvl_year, x = 's1_q1' , y = 'count', hue ='year',   saturation=0.5, 
            order =  ['Associate','Analyst','Senior Analyst',  'Manager',  'Senior Manager',  
      'Director/Senior Director', 'VP and above',
       'No response'] , 
    width=0.7, ax = ax)
plt.xticks( rotation = 90, fontsize=7 )
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
df['s1_q1_regroup']  = np.where(df['s1_q1'] == 'No response', 'No response', 
                                np.where( df['s1_q1'].isin(['Associate', 'Analyst', 'Senior Analyst' ]), 'IC', 
                                np.where( df['s1_q1'].isin(['Manager', 'Senior Manager'  ]), 'Mgr&SR Mgr', 
                                'Director&Above' )))
# df.groupby('year', as_index = False)['s1_q1_regroup'].value_counts( )
# new members join in wwn? if so , what are their job level?
# the hypothesis is that, the increase in  pl might due to ic get promoted?

# %%
member_by_job_lvl_grp_year = df.groupby('year', as_index = False)['s1_q1_regroup'].value_counts( )

# %%
# df.groupby('s1_q1_regroup')['year'].value_counts()#.groupby('s1_q1_regroup').diff()
fig, ax = plt.subplots (figsize= (4,3))
sns.barplot(member_by_job_lvl_grp_year, x = 's1_q1_regroup' , y = 'count', hue ='year',   saturation=0.5, 
            order =  ['IC', 'Mgr&SR Mgr', 'Director&Above', 'No response'] , width=0.7, ax = ax)
plt.xticks( rotation = 90, fontsize=7 )
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
# pd.pivot(data= df.groupby('year', as_index = False)['s1_q1_regroup'].value_counts( ),\
#          index = 'year', columns='s1_q1_regroup', values='count' ).pct_change().mul(100).dropna()
# # we can see more pl join wwn in year 2022 as compared to 2021

# %% [markdown]
# ### New members increase/drop by job level as compared to prev year ?
# - assumption: <1 year -> new member

# %%
df [df['s1_q5'] == 'Less than 1 year' ].groupby('year', as_index = False)['s1_q1'].value_counts().groupby(['s1_q1'] + ['year']).max()#.reset_index().groupby(['s1_q1'])['count'].diff()
# Out:
#                                count
# s1_q1                    year
# Analyst                  2021      4
#                          2022      6
# Associate                2021     10
#                          2022     11
# Director/Senior Director 2021      1
#                          2022      3
# Manager                  2021      3
#                          2022      9
# Senior Analyst           2021     10
#                          2022      3
# Senior Manager           2021      3
#                          2022      2
# VP and above             2021      1

# %% [markdown]
# ##  job function
# - Qiqi's suggestion: this need a bit clean up - can we adopot the org chart? list out the functions for wwn members, and only ask for user input if no one from her org joined wwn before ; this will help to prevent typo, and in turn, gives better data quality

# %%
s1_q2_default_vaue = [ 'Finance', 
                'GIS', 
                'GPO', 
                'GSS', 
                'HR', 
                'Integrated Supply Chain/ISC', 
                'Legal', 
                'Manufacturing', 
                 'Sales', 
                'Marketing' ]

# %%
import re

# %%
def _group_cx(x ): 
    
    if str(x) == 'nan': 
        return x
    else: 
        _x = x.lower()
        if 'service' in _x or 'call'  in _x or 'cct' in _x or 'call' in _x or 'cx' in _x : 
            return 'Customer Service'
        else: 
            return x

# %%
df['s1_q2'] = df['s1_q2'].apply( lambda x : _group_cx(x))

# %%
# customer service & customer services are the same, the error is due to user input
df['s1_q2_regroup'] =  np.where ( df['s1_q2'].isin( s1_q2_default_vaue + ['Communications'] +   ['Customer Service'] ),
                                 df['s1_q2'], 
                                 np.where(df['s1_q2'].isnull(), np.nan,  'Other'))

# %%
df['s1_q2_regroup'] .value_counts()
# Out:
# s1_q2_regroup
# Sales                          62
# Marketing                      51
# GPO                            48
# Integrated Supply Chain/ISC    43
# Other                          30
# Customer Service               27
# Finance                        25
# GSS                            23
# Legal                          16
# GIS                            13
# Communications                 13
# HR                             13
# Manufacturing                  10
# nan                             3
# Name: count, dtype: int64

# %% [markdown]
# ##  1.3 Location
# - Qiqi's comment: why we need to understand member's location? for example, if more members are remotely working, then should we consider adding more online events?
# - same as function, need bit of data cleaning/ restricted user input

# %%
s1_q3_default_vaue = ['Saint Joseph/Benton Harbor', 'Remote', 'Manufacturing Facility']

# %%
df['s1_q3_regroup'] = np.where( df['s1_q3'].isin(s1_q3_default_vaue), df['s1_q3'], 'Other' )

# %%
df['s1_q3_regroup'].value_counts()
# Out:
# s1_q3_regroup
# Saint Joseph/Benton Harbor    246
# Remote                         92
# Manufacturing Facility         21
# Other                          18
# Name: count, dtype: int64

# %% [markdown]
# ## 1.4 : how long have you been at whirlpool?

# %%
s1_q4_default_vaue = ['4-9 years', '10+ years', '1-3 years', 'Less than 1 year' ]

# %%
df['s1_q4'] .value_counts(dropna = False)
# Out:
# s1_q4
# 10+ years           146
# 4-9 years           140
# 1-3 years            74
# Less than 1 year     16
# NaN                   1
# Name: count, dtype: int64

# %%
df['s1_q4_regroup'] = np.where( df['s1_q4'].isin(s1_q4_default_vaue), df['s1_q4'], 'No response' )

# %%
# which yoe level does wwn attracts most
df.groupby(["s1_q4_regroup", "year"]).size().groupby("s1_q4_regroup").pct_change()
# Out:
# s1_q4_regroup     year
# 1-3 years         2021         NaN
#                   2022   -0.279070
# 10+ years         2021         NaN
#                   2022   -0.053333
# 4-9 years         2021         NaN
#                   2022   -0.028169
# Less than 1 year  2021         NaN
#                   2022    1.200000
# No response       2022         NaN
# dtype: float64

# %% [markdown]
# ## 1.5 : How long have you been a member of WWN?
# * Qiqi question: can we consider the members than have been at wwn for less 1  year  as "new joins"

# %%
df['s1_q5'] .value_counts(dropna = False)
# Out:
# s1_q5
# 1-3 years           155
# 4-9 years           128
# Less than 1 year     66
# 10+ years            28
# Name: count, dtype: int64

# %%
s1_q5_default_vaue = ['1-3 years1_q5_default_vaue = s', '4-9 years', 'Less than 1 year', '10+ years']

# %%
df['s1_q5_regroup'] = np.where( df['s1_q5'].isin(s1_q5_default_vaue), df['s1_q5'], 'No response' )

# %%
# new joins: been in wwn for less than 1 year?? 
# among the  wwn new joins, how long then been at whirlpool
df[df['s1_q5_regroup'] == 'Less than 1 year'].groupby(['s1_q4_regroup', 'year']).size()
# Out:
# s1_q4_regroup     year
# 1-3 years         2021    14
#                   2022     9
# 10+ years         2021     6
#                   2022     7
# 4-9 years         2021     7
#                   2022     7
# Less than 1 year  2021     5
#                   2022    11
# dtype: int64

# %% [markdown]
# # Section 2:  How can WWN support you?

# %% [markdown]
# ## 2.1 There are policies, benefits, and initiatives in place to ensure my success as a woman at Whirlpool.
# * score based

# %%
df.groupby('year')['s2_q1'].value_counts()
# Out:
# year  s2_q1
# 2021  4.0      85
#       3.0      51
#       5.0      35
#       2.0      14
#       1.0       5
# 2022  4.0      90
#       3.0      43
#       5.0      32
#       2.0       8
# Name: count, dtype: int64

# %%
df.groupby(['year', 's1_q4_regroup']) ['s2_q1'].median()
# Out:
# year  s1_q4_regroup
# 2021  1-3 years           4.0
#       10+ years           4.0
#       4-9 years           4.0
#       Less than 1 year    3.0
# 2022  1-3 years           4.0
#       10+ years           4.0
#       4-9 years           4.0
#       Less than 1 year    4.0
#       No response         3.0
# Name: s2_q1, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(data = df , y  = "s1_q4_regroup", x  = 's2_q1'  )
# Out:
# <AxesSubplot:xlabel='s2_q1', ylabel='s1_q4_regroup'>

# %% [markdown]
# ## 2.2 The Every Day Performance Excellence process is successful in differentiating talent and supporting advancement for women at Whirlpool.

# %%
df.groupby('year')['s2_q2'].median()
# Out:
# year
# 2021    3.0
# 2022    4.0
# Name: s2_q2, dtype: float64

# %%
df.groupby(['year', 's1_q4_regroup']) ['s2_q2'].describe()
# Out:
#                        count      mean       std  min  25%  50%  75%  max
# year s1_q4_regroup
# 2021 1-3 years          43.0  3.395349  1.072148  1.0  3.0  3.0  4.0  5.0
#      10+ years          75.0  3.400000  0.972598  1.0  3.0  3.0  4.0  5.0
#      4-9 years          69.0  3.304348  1.102195  1.0  3.0  3.0  4.0  5.0
#      Less than 1 year    5.0  3.400000  0.547723  3.0  3.0  3.0  4.0  4.0
# 2022 1-3 years          31.0  3.354839  0.838586  2.0  3.0  3.0  4.0  5.0
#      10+ years          70.0  3.485714  1.017853  1.0  3.0  4.0  4.0  5.0
#      4-9 years          69.0  3.434783  0.992298  1.0  3.0  4.0  4.0  5.0
#      Less than 1 year   11.0  3.363636  0.809040  2.0  3.0  3.0  4.0  5.0
#      No response         1.0  3.000000       NaN  3.0  3.0  3.0  3.0  3.0

# %% [markdown]
# ## 2.3 What Whirlpool policy, benefit, or initiative is most supportive of your career development?

# %%
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# print(stopwords.words('english'))
import operator
import spacy
from nltk import bigrams, FreqDist, ngrams
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wuq2\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# from nltk.stem import WordNetLemmatizer
# nltk.download("wordnet")
# nltk.download("omw-1.4")

# %%
def _clean_txt(x): 
    if str(x) == 'nan': 
        return x 
    else: 
        return re.sub('[^A-Za-z]+', ' ', x).lower()

# %%
def _lemmatize_word(spacy_model,line, STOPWORD_LIST ) : 
    """clean the text, lemmatized the word, then excludethe non-noun word
    return: list of lemmatized words
    """
    # # excluded tags
    excluded_tags = { "VERB", "ADJ", "ADV", "ADP", "PROPN"}
    _lemmatize_word = []
    doc = spacy_model(line)
    for token in doc:
        if  token.pos_ not in excluded_tags and token.text not in STOPWORD_LIST: 
            if len(token.text.strip()) > 0: # keep the token with a character
                _lemmatize_word += [token.lemma_] 
    return _lemmatize_word

# %%
def _plot_word_cloud( ngram_freq_dict, stopwords_list):
    # plot the wordcloud, to show the benefits that wwn members most valued 
    wordcloud = WordCloud(stopwords=stopwords_list,  background_color="white").generate_from_frequencies(ngram_freq_dict)
    # Display the generated image:
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
def word_cloud_gen_wrapper(col, data,  stopwords_list, ngram = 2, ngram_freq_thres = 3   ): 
    data[col] = data[col].apply(lambda x : _clean_txt(x))
    text = "; ".join(comment.lower() if ( str(comment) != 'nan' ) &  (comment != 'none') else "" for comment in data[col])
    nlp = spacy.load('en_core_web_sm') 

    lemmatized_word_list = []
    for _line in text.split("; "):
        lemmatized_word_list += _lemmatize_word(nlp,_line, stopwords_list)
    # bigrams and count the freq
    ngram_freq_dist = FreqDist(ngrams(lemmatized_word_list, ngram ))  
    #trigram_freq_dist = FreqDist(ngrams(lemmatized_word_list,3 )) 
    
    # combine the bigrams into a single term
    ngram_freq_dict = {} 
    for _k,v in sorted(ngram_freq_dist.items(), key= operator.itemgetter(1), reverse=True):
        k = " ".join (_k )
        if v >= ngram_freq_thres: 
            ngram_freq_dict[k]  = v
   
    _plot_word_cloud( ngram_freq_dict, stopwords_list)
    return  ngram_freq_dist

# %%
STOPWORD_LIST = list ( stopwords.words('english') )  + ['none']  + ['whirlpool', 'women', 'network']  + ['work']

# %%
ngram_freq_dist = word_cloud_gen_wrapper('s2_q3', df , STOPWORD_LIST, ngram = 2, ngram_freq_thres = 2   )

# %%
ngram_freq_dist
# Out:
# FreqDist({('career', 'compass'): 17, ('maternity', 'leave'): 13, ('career', 'development'): 8, ('mentorship', 'program'): 5, ('education', 'reimbursement'): 4, ('people', 'leader'): 3, ('maternity', 'benefit'): 3, ('development', 'plan'): 3, ('life', 'balance'): 3, ('core', 'day'): 2, ...})

# %%
# df['s2_q3'].dropna().values

# %% [markdown]
# ## 2.4 What __new__ Whirlpool policy, benefit, or initiative would be most beneficial to your career development?

# %%
df['s2_q4'].dropna().values
# Out:
# array(['- A new rating system \n- Promotions allowed to remote employees ',
#        '9 box transparency and coaching',
#        "A better policy on fragrances.  Spectrum (Lakeland) doesn't allow any employees to wear perfumes or cologne.   Mentorship.",
#        "A discussion of how to feel respected in your current role even if others don't necessarily make you feel respected - what and I do personally to feel better about myself and my contributions?",
#        'A mentor/sponsorship program to help advocate for our career growth throughout the organization.',
# ...

# %%
word_cloud_gen_wrapper('s2_q4', df , STOPWORD_LIST  , ngram = 2  , ngram_freq_thres = 3    )
# Out:
# FreqDist({('maternity', 'leave'): 12, ('career', 'development'): 8, ('day', 'day'): 4, ('leave', 'policy'): 4, ('child', 'care'): 3, ('x', 'month'): 3, ('leadership', 'program'): 3, ('would', 'career'): 3, ('child', 'child'): 3, ('vacation', 'time'): 3, ...})

# %% [markdown]
# ## 2.5 What area would you most like to see WWN focus on in 2022?  **

# %%
# s2_q5_default_vaue = [s.lower() for s in s2_q5_default_vaue]

# %%
import collections

# %%
counter =  collections.Counter( sum(  [ val.strip() .split(", ")  for val in df['s2_q5'].dropna().values ], []  ) )

# %%
{tup[0] : tup[1 ] for tup in counter.most_common() if tup[1] > 1  }
# Out:
# {'Personal Development': 178,
#  'Exposure to Female Leaders': 148,
#  'Mentorship': 123,
#  'Whirlpool Policies/Benefits': 122,
#  'Flexibility / Work-Life Balance': 109,
#  'Networking': 59,
#  'Sponsorship': 4}

# %%
# count_occurrence= {k.title(): counter.get(k ) for k in s2_q5_default_vaue } 
# count_occurrence

# %%
# other_response =  '' 
# for row in df['s2_q5'].dropna().values: 

#     row = row.lower().strip()
#     _other = [] 
#     for choice in s2_q5_default_vaue: 
#         row = row.replace(choice, '')
#         row = row.replace(',', '')
#     if row.strip() != '': 
#         _other.append( row.strip()) 
#     if  len(_other) > 0  :
#         other_response += _clean_txt(_other[ 0])  + '\n'    
#     # for _v in row  :
#     #     if _v not in s2_q5_default_vaue: 
#     #         _other.append(_v.strip())
#     # other_response.append(_other )

# %%
# lemmatized_word_list = []
# nlp = spacy.load('en_core_web_sm') 
# for _line in other_response.split("\n"):
#     lemmatized_word_list += _lemmatize_word(nlp,_line, STOPWORD_LIST)

# %%
# other_response_counter =  collections.Counter(  lemmatized_word_list )

# %%
# other_response_counter
# Out:
# Counter({'sponsorship': 8,
#          'exposure': 4,
#          'talent': 3,
#          'career': 3,
#          'leader': 2,
#          'area': 2,
#          'balance': 2,
#          'everyone': 1,
#          'we': 1,
#          'director': 1,
#          'pool': 1,
#          'rating': 1,
#          'performance': 1,
#          'review': 1,
#          'preparation': 1,
#          'workshop': 1,
#          'manufacturing': 1,
#          'plant': 1,
#          'policy': 1,
#          'education': 1,
#          'element': 1,
#          'leadership': 1,
#          'year': 1,
#          'progression': 1,
#          'woman': 1,
#          'family': 1,
#          'right': 1,
#          'manager': 1,
#          'development': 1,
#          'path': 1,
#          'ladder': 1,
#          'yes': 1,
#          'wp': 1,
#          'life': 1,
#          'something': 1,
#          'people': 1,
#          'man': 1,
#          'female': 1,
#          'trade': 1,
#          'off': 1,
# ...

# %% [markdown]
# ## 2.6 In the past year, which WWN initiatives have you leveraged? Please select all that apply:

# %%
counter =  collections.Counter( sum(  [ val.strip() .split(", ")  for val in df['s2_q6'].dropna().values ], []  ) )

# %%
{tup[0] : tup[1 ] for tup in counter.most_common() if tup[1] > 1  }
# Out:
# {'Networking / Social Events': 172,
#  'Speak Up for Diversity': 127,
#  'Career Compass Round Robin': 87,
#  'Personal Branding': 83,
#  'Courageous Conversations': 82,
#  'None of the Above': 74,
#  'Culture Catalyst Training': 51,
#  'Policy Education': 33}

# %% [markdown]
# ## 2.7 In the past year, which Whirlpool employee resources have you leveraged? Please select all that apply:

# %%
counter =  collections.Counter( sum(  [ val.strip() .split(", ")  for val in df['s2_q7'].dropna().values ], []  ) )

# %%
{tup[0] : tup[1 ] for tup in counter.most_common() if tup[1] > 1  }
# Out:
# {'Other ERGs': 148,
#  'Whirlpool Human Resources': 116,
#  'None of the Above': 77,
#  'Be*Well Pathways / Resources': 76,
#  'Employee Well-Being & Support Channel / WHR360': 68,
#  'Whirlpool Health Coach': 66,
#  'LifeWorks': 34,
#  'Lifeworks Health': 22,
#  'Lifeworks Family': 8,
#  'Lifeworks Money': 7,
#  'Lifeworks Life': 6,
#  'Lifeworks Work': 3}

# %% [markdown]
# # Section 3: Thank you for being part of WWN!

# %% [markdown]
# ## 3.1 I understand WWN’s mission to successfully create an inclusive & equitable environment that enables a natural desire to stay & be committed to Whirlpool.

# %%
import seaborn as sns

# %%
sns.countplot(x=df["s3_q1"])
# Out:
# <AxesSubplot:xlabel='s3_q1', ylabel='count'>

# %%
# sns.boxplot(x=df["s3_q1"])

# %% [markdown]
# ##  3.2 I am actively engaged in WWN activities that help drive an inclusive & equitable environment that enables a natural desire to stay & be committed to Whirlpool.

# %%
sns.countplot(x=df["s3_q2"])
# Out:
# <AxesSubplot:xlabel='s3_q2', ylabel='count'>

# %% [markdown]
# ## 3.3  If you are not currently actively engaged in WWN, what would inspire you to become more involved?

# %%
df['s3_q3'].dropna().values
# Out:
# array(['I wish that the pillars got together more to share what each pillar is working on. I believe the Pillar Leads do this monthly/quarterly but the employees do not get to see other than the kick off meeting, what other groups are working on. \n',
#        "I don't know.  I'm mentally exhausted.",
#        'I have to many other commitments in my role and my manager is not supportive of me spending time elsewhere',
#        'Encouragement from my People Leader to be involved and to carve out time to be engaged in WWN or other ERG activities. Right now, I dont have the time to do other things outside of my core work.',
# ...

# %% [markdown]
# ## 3.4 Why is supporting WWN important to you (as a female or an ally)?

# %%
df['s3_q4'].dropna().values
# Out:
# array(['Supporting the WWN allows me to make Whirlpool & companies around the world better for females that join after me. I believe it is my duty to make the work place continually better for women. ',
#        'fighting for fertility benefits',
#        "I think it is important for women.   I wish I had this type of support when I started at Whirlpool.  I had great people to work with and didn't see the equality issues until I went to the GIS org a few years after being in Marketing.   I've been back and forth over the years, and I still feel like GIS is male dominated.  It was not a pleasant experience back in the 90s.  It has gotten much better, but they have seem women in leadership positions leave since the pandemic started.  ",
#        "I want to feel respected and to feel that I don't have to be quiet or downplay my value to fit in",
# ...

# %% [markdown]
# ## 3.5 How could WWN make the biggest impact for women at Whirlpool in the coming year?

# %%
df['s3_q5'].dropna().values
# Out:
# array(['- Ability to work remote and get promoted, like other companies are doing. \n',
#        "There has been a lot of turnover.  Maybe find ways to keep women in their leadership positions.  Especially in the GIS area.   Also, I see a lot of female contractors that are very qualified for roles they are in.  Why aren't they hired?",
#        'Keep making progress like you are!',
#        'Encourage an organization-wide work schedule that allows employees to have a better work/life balance. 4 day work weeks, or meeting rules that discourages early morning or end of the work day meetings. ',
#        'Make the time I am spending at work, valuable and meaningful; recognized and rewarded. Make me feel supported and motivated.\nShow me meaningful progress.\nShow me a plan for creating a diverse representation of women voices. \nCommit to empowering women at all levels in their careers. period.\nCreate a safe space for sharing struggles, frustrations, wins, etc.',
# ...
